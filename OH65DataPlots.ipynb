# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from astropy.io import ascii
import celerite

from astropy import units as u
from astropy import constants as const
import numpy as np
from lmfit import Model, minimize, Parameters, report_fit
from lmfit.models import GaussianModel, PolynomialModel

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH119210p2000_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('119210p2000_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH119380p3967_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('119380p3967_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH120500p1863_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('120500p1863_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH120500p2963_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('120500p2963_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH121070p2175_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('121070p2175_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH121930p1975_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('121930p1975_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH122220p1875_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('122220p1875_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH122290p4133_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('122290p4133_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH122500p2900_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('122500p2900_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH123360p2075_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('123360p2075_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH123500p1963_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('123500p1963_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH125070p1950_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('125070p1950_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH125220p3250_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('125220p3250_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH125500p2200_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('125500p2200_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH126500p3250_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('126500p3250_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH127500p2088_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('127500p2088_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH131430p4667_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('131430p4667_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH132220p3167_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('132220p3167_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH134570p3400_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('134570p3400_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH137160p4300_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('137160p4300_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH142210p2325_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('142210p2325_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH143000p3850_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('143000p3850_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH146070p1775_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('146070p1775_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH146200p3963_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('146200p3963_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH146930p2075_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('146930p2075_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH147000p4038_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('147000p4038_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH147200p4075_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('147200p4075_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH148200p3863_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('148200p3863_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH148210p2350_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('148210p2350_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH150120p4067_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('150120p4067_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH151500p1925_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('151500p1925_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH153640p1925_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('153640p1925_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH155670p2133_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('155670p2133_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH156540p3513_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('156540p3513_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH156640p3250_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('156640p3250_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH157350p2200_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('157350p2200_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH199070p2800_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('199070p2800_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data
OHdata65 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1665 Profile/OH199380p3967_65.ascii', data_start=4)
vel65 = OHdata65['col1']
Ta65 = OHdata65['col2']

# Galactic range choice:
igood = np.where((vel65 >= -1340) & (vel65 <= 1700))
# Select Galactic range:
vel65 = vel65[igood]
Ta65 = Ta65[igood]
plt.plot(vel65, Ta65)
plt.title('199380p3967_65')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

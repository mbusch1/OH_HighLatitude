# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from astropy.io import ascii
import celerite

from astropy import units as u
from astropy import constants as const
import numpy as np
from lmfit import Model, minimize, Parameters, report_fit
from lmfit.models import GaussianModel, PolynomialModel

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH119210p2000_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('119210p2000_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH119380p3967_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('119380p3967_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH120500p1863_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('120500p1863_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH120500p2963_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('120500p2963_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH121070p2175_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('121070p2175_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH121930p1975_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('121930p1975_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH122220p1875_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('122220p1875_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH122290p4133_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('122290p4133_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH122500p2900_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('122500p2900_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH123360p2075_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('123360p2075_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH123500p1963_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('123500p1963_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH125070p1950_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('125070p1950_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH125220p3250_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('125220p3250_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH125500p2200_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('125500p2200_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH126500p3250_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('126500p3250_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH127500p2088_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('127500p2088_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH131430p4667_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('131430p4667_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH132220p3167_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('132220p3167_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH134570p3400_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('134570p3400_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH137160p4300_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('137160p4300_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH142210p2325_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('142210p2325_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH143000p3850_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('143000p3850_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH146070p1775_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('146070p1775_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH146200p3963_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('146200p3963_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH146930p2075_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('146930p2075_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH147000p4038_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('147000p4038_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH147200p4075_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('147200p4075_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH148200p3863_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('148200p3863_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH148210p2350_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('148210p2350_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH150120p4067_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('150120p4067_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH151500p1925_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('151500p1925_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH153640p1925_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('153640p1925_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH155670p2133_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('155670p2133_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH156540p3513_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('156540p3513_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH156640p3250_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('156640p3250_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH157350p2200_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('157350p2200_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH199070p2800_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('199070p2800_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)

# %%
# Load the 67 Data:
OHdata67 = ascii.read('C:/Users/seven/OneDrive/Documents/OH Data 1667 Profile/OH119380p3967_67.ascii', data_start=4)
vel67 = OHdata67['col1']
Ta67 = OHdata67['col2']

# Galactic range choice:
igood = np.where((vel67 >= -1340) & (vel67 <= 1700))
# Select Galactic range:
vel67 = vel67[igood]
Ta67 = Ta67[igood]
plt.plot(vel67, Ta67)
plt.title('119380p3967_67')
plt.axhline(0)
plt.xlim([-400, 400])
# Out:
# (-400.0, 400.0)
